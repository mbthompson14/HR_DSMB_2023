# %%
import pandas as pd

# %%
df = pd.read_csv('for_mini_risk.csv')
df
# Out:
#     record_id redcap_event_name  redcap_survey_identifier  partstatus  \
# 0    CF017AUD    baseline_arm_3                       NaN         2.0
# 1    CF017AUD      week_3_arm_3                       NaN         2.0
# 2    CF017AUD      week_6_arm_3                       NaN         2.0
# 3    CF017AUD     week_10_arm_3                       NaN         2.0
# 4    CF017AUD     week_14_arm_3                       NaN         2.0
# ..        ...               ...                       ...         ...
# 868  PM298AUD    baseline_arm_3                       NaN        99.0
# 869  PM299AUD    baseline_arm_3                       NaN        99.0
# 870  PM300AUD    baseline_arm_3                       NaN        99.0
# 871  PM307AUD    baseline_arm_3                       NaN        99.0
# 872  PM308AUD    baseline_arm_3                       NaN        99.0
#
#           mini_timestamp  mini_suicide_sum  mini_suicide_dx  \
# 0    2021-11-19 10:12:04               0.0              0.0
# 1                    NaN               NaN              NaN
# 2                    NaN               NaN              NaN
# 3                    NaN               NaN              NaN
# 4                    NaN               NaN              NaN
# ..                   ...               ...              ...
# 868                  NaN               0.0              NaN
# 869                  NaN               0.0              NaN
# 870                  NaN               0.0              NaN
# 871                  NaN               0.0              NaN
# 872                  NaN               0.0              NaN
#
#      mini_suicide_dx_2 suicide_notes suicide_protective  ... phq8_1  phq8_2  \
# 0                  1.0           NaN                NaN  ...    1.0     0.0
# 1                  NaN           NaN                NaN  ...    NaN     NaN
# 2                  NaN           NaN                NaN  ...    NaN     NaN
# 3                  NaN           NaN                NaN  ...    NaN     NaN
# 4                  NaN           NaN                NaN  ...    NaN     NaN
# ..                 ...           ...                ...  ...    ...     ...
# 868                NaN           NaN                NaN  ...    NaN     NaN
# 869                NaN           NaN                NaN  ...    NaN     NaN
# 870                NaN           NaN                NaN  ...    NaN     NaN
# 871                NaN           NaN                NaN  ...    NaN     NaN
# 872                NaN           NaN                NaN  ...    NaN     NaN
#
#      phq8_3 phq8_4  phq8_5  phq8_6  phq8_7  phq8_8  phq8_total_score  \
# 0       3.0    1.0     2.0     0.0     2.0     3.0              12.0
# 1       NaN    NaN     NaN     NaN     NaN     NaN               NaN
# 2       NaN    NaN     NaN     NaN     NaN     NaN               NaN
# 3       NaN    NaN     NaN     NaN     NaN     NaN               NaN
# 4       NaN    NaN     NaN     NaN     NaN     NaN               NaN
# ..      ...    ...     ...     ...     ...     ...               ...
# 868     NaN    NaN     NaN     NaN     NaN     NaN               NaN
# 869     NaN    NaN     NaN     NaN     NaN     NaN               NaN
# 870     NaN    NaN     NaN     NaN     NaN     NaN               NaN
# 871     NaN    NaN     NaN     NaN     NaN     NaN               NaN
# 872     NaN    NaN     NaN     NaN     NaN     NaN               NaN
#
#      patient_health_questionnaire_complete
# 0                                      2.0
# 1                                      NaN
# 2                                      0.0
# 3                                      0.0
# 4                                      0.0
# ..                                     ...
# 868                                    0.0
# 869                                    0.0
# 870                                    0.0
# 871                                    0.0
# 872                                    0.0
#
# [873 rows x 61 columns]

# %%
df.loc[df['mini_suicide_sum']>=2].to_csv('mini_suicide_scores_2023.csv', index=False)
