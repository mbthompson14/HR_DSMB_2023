# %%
import pandas as pd

# %%
df = pd.read_csv('for_mini_risk.csv')
df
# Out:
#     record_id redcap_event_name  partstatus  mini_suicide_sum  \
# 0    CF017AUD    baseline_arm_3         2.0               0.0
# 1    CF017AUD      week_3_arm_3         2.0               NaN
# 2    CF017AUD      week_6_arm_3         2.0               NaN
# 3    CF017AUD     week_10_arm_3         2.0               NaN
# 4    CF017AUD     week_14_arm_3         2.0               NaN
# ..        ...               ...         ...               ...
# 836  PM298AUD    baseline_arm_3        99.0               0.0
# 837  PM299AUD    baseline_arm_3        99.0               0.0
# 838  PM300AUD    baseline_arm_3        99.0               0.0
# 839  PM307AUD    baseline_arm_3        99.0               0.0
# 840  PM308AUD    baseline_arm_3        99.0               0.0
#
#      mini_suicide_dx  mini_suicide_dx_2 suicide_notes suicide_protective  \
# 0                0.0                1.0           NaN                NaN
# ...

# %%
df.loc[df['mini_suicide_sum']>=2].to_csv('mini_suicide_scores_2023.csv', index=False)
